# %% [markdown]
# # Lec_2
# ## Анализ данных с библиотекой Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series
# Она представляет из себя объект, похожий на одномерный массив,но отличительной чертой является наличие индексов. Индекс находится слева, а сам элемент - справа.
#
# Синтаксис создания:
#
# pandas.Series(input_data,index, data_type)
#
# - input_data: ввод в виде списка,константы,массива NumPy,Dict и тд.
# - index: значение индексов.
# - data_type (опционально): тип данных.

# %%
a = pd.Series([1,2,3,4,5],
                 index = ["one", 'two', 'three', 'four', 'five'])
a
# Out:
# one      1
# two      2
# three    3
# four     4
# five     5
# dtype: int64

# %%
a = pd.Series([1,2,3,4,5])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
a.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
a[0]
# Out:
# 1

# %%
a[1]
# Out:
# 2

# %%
a['one']
# Out:
# 1

# %% [markdown]
# ### DataFrame
# Объект dataframe явдяется табличной структурой данныъ. В любой таблице всегда присутствуют строки и столбцы. При этом в столбцах можно хранить данные разных типов данных. Столбцами в объекте DataFrame выступают объекты Series, строки которых являются их элементами.
#
# Синтаксис создания:
#
# pandas.DataFrame(input_data, index)
#
# - input data: ввод в виде Dict,2D массива NumPy,Series и тд.
# - index: значение индексов

# %%
df = pd.DataFrame({
    'Age': [46,37,44,42,42],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female','Female','Male','Male','Male',]
})
df
# Out:
#    Age  Country  Gender
# 0   46    Spain  Female
# 1   37    Spain  Female
# 2   44  Germany    Male
# 3   42  Germany    Male
# 4   42   France    Male

# %%
df['Age']
# Out:
# 0    46
# 1    37
# 2    44
# 3    42
# 4    42
# Name: Age, dtype: int64

# %%
df.Country
# Out:
# 0      Spain
# 1      Spain
# 2    Germany
# 3    Germany
# 4     France
# Name: Country, dtype: object

# %%
df[['Country', 'Age']]
# Out:
#    Country  Age
# 0    Spain   46
# 1    Spain   37
# 2  Germany   44
# 3  Germany   42
# 4   France   42

# %%
df.columns
# Out:
# Index(['Age', 'Country', 'Gender'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df = pd.DataFrame({
    'Age': [46,37,44,42,42],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female','Female','Male','Male','Male',]
}, index=[5,4,6,3,2])
df
# Out:
#    Age  Country  Gender
# 5   46    Spain  Female
# 4   37    Spain  Female
# 6   44  Germany    Male
# 3   42  Germany    Male
# 2   42   France    Male

# %%
df.index = [101,102,103,104,105]
df
# Out:
#      Age  Country  Gender
# 101   46    Spain  Female
# 102   37    Spain  Female
# 103   44  Germany    Male
# 104   42  Germany    Male
# 105   42   France    Male

# %% [markdown]
# ### Считывание данных
# В целом, pandas поддерживает все самые популярные форматы хранения данных: csv, excel, sql, html и многое
# другое, но чаще всего приходится работать именно с csv файлами (comma separated values)

# %%
df = pd.read_csv('/Users/SmirnovAnton/Downloads/Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
pd.read_csv('/Users/SmirnovAnton/Downloads/Churn_Modelling.csv',header=0)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Вызов таблицы с шапкой (можно менять)

# %%
pd.read_csv('/Users/SmirnovAnton/Downloads/Churn_Modelling.csv',sep=',')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# вызов таблицы с разделителем ","

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Вызов таблицы через переменную

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %% [markdown]
# Отображает первые 5 строк(в данном случае 2, можно менять)

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# Отображает последние 5 строк(можно отображать нужное кол-во)

# %%
df.sample()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 5280       5281    15694129  Summers          569   Germany  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5280       3  100032.52              1          1               0
#
#       EstimatedSalary  Exited
# 5280          5159.21       1

# %% [markdown]
# Вызывает рандомную строку

# %%
df.sample(frac=1)
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 3103       3104    15766609         Jowers          655    France  Female
# 6420       6421    15718039       Ferguson          606   Germany  Female
# 8220       8221    15727177        Manfrin          557    France    Male
# 4900       4901    15634936  Chukwukadibia          735    France    Male
# 7072       7073    15775750            Yao          686    France    Male
# ...         ...         ...            ...          ...       ...     ...
# 8592       8593    15638774          Chong          719     Spain  Female
# 9451       9452    15571586         Briggs          524     Spain    Male
# 4608       4609    15614103        Colombo          850   Germany    Male
# 9094       9095    15574169      Trevisano          595   Germany  Female
# 5757       5758    15601417          T'ang          681    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Возврат всех строчек в рандомном порядке

# %%
df.sample(frac=0.5)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 7399       7400    15769548      Hyde          668    France  Female   37
# 7538       7539    15728082  Vasiliev          601     Spain    Male   28
# 1185       1186    15795228   Stewart          756    France    Male   37
# 156         157    15655007        Li          758    France  Female   33
# 396         397    15584766    Knight          557    France    Male   33
# ...         ...         ...       ...          ...       ...     ...  ...
# 6075       6076    15781451    Buccho          504    France    Male   42
# 9427       9428    15584812    Overby          693     Spain  Female   39
# 924         925    15658485     Heath          785    France  Female   34
# 8546       8547    15686957    Piccio          553   Germany    Male   35
# 2824       2825    15667938     Hurst          628    France    Male   32
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Возврат половины таблицы в рандомном порядке

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# кортеж с размерностью таблицы

# %% [markdown]
# ### Первичный анализ
# Типы данных:
# -	int: целочисленные значения. Пример: 9, 56, 30
# -	float: вещественные значения (с плавающей точкой). Пример: 7.3, 9.0, 45.334
# -	object/str: строковые значения. Пример: ‘hello, world’, ‘50 000’

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Выводятся значения:
# 1.	Count - количество непропущенных объектов (там, где нет nan значений)
# 2.	mean - арифметическое среднее
# 3.	std - стандартное отклонение
# 4.	min - минимальное значение
# 5.	25% - квантиль 25 процентов
# 6.	50% - квантиль 50 процентов или же медиана
# 7.	75% - квантиль 75 процентов
# 8.	max - максимальное значение

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Balance'].max()
# Out:
# 250898.09

# %%
df[['CreditScore','Age','Tenure']].mean()
# Out:
# CreditScore    650.5288
# Age             38.9218
# Tenure           5.0128
# dtype: float64

# %%
df.describe(include=['object'])
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %% [markdown]
# Получаем 4 значения:
# 1.	count - количество непропущенных объектов
# 2.	unique - количество уникальных значений
# 3.	top - самое частотное значение (мода)
# 4.	freq - частота появления самого частотного значения

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'].astype('bool')
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999     True
# Name: HasCrCard, Length: 10000, dtype: bool

# %%
df['HasCrCard'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'] = df['HasCrCard'].astype('bool')

# %%
df['HasCrCard'].dtype
# Out:
# dtype('bool')

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Geography'].value_counts(normalize=True)
# Out:
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64

# %% [markdown]
# ### Фильтрация
# Фильтрация в pandas основывается на булевых масках.
#
# Булевая маска — бинарные данные, которые используются для выбора определенных объектов из
#
# структуры данных.

# %%
df['Gender']=='Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
male = df[df['Gender']=='Male']
male
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography Gender  Age  \
# 5             6    15574012          Chu          645     Spain   Male   44
# 6             7    15592531     Bartlett          822    France   Male   50
# 8             9    15792365           He          501    France   Male   44
# 9            10    15592389           H?          684    France   Male   27
# 10           11    15767821       Bearce          528    France   Male   31
# ...         ...         ...          ...          ...       ...    ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain   Male   36
# 9993       9994    15569266       Rahman          644    France   Male   28
# 9995       9996    15606229     Obijiaku          771    France   Male   39
# 9996       9997    15569892    Johnstone          516    France   Male   35
# 9998       9999    15682355    Sabbatini          772   Germany   Male   42
#
# ...

# %% [markdown]
# ### Логическое И
# При операторе & нужно, чтобы выполнялось два условия одновременно, чтобы у объекта был женский
# пол (df[‘Gender’] == ‘Female’) и чтобы количество продуктов, которыми пользуется клиент было больше или
# равно 3 (df[‘NumOfProducts’] >= 3)

# %%
df[(df['Gender'] == 'Female') & (df['NumOfProducts'] >= 3)]
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 2             3    15619304           Onio          502    France  Female
# 7             8    15656148         Obinna          376   Germany  Female
# 30           31    15589475        Azikiwe          591     Spain  Female
# 88           89    15622897         Sharpe          646    France  Female
# 90           91    15757535           Heap          647     Spain  Female
# ...         ...         ...            ...          ...       ...     ...
# 9565       9566    15752294           Long          582    France  Female
# 9747       9748    15775761  Iweobiegbunam          610   Germany  Female
# 9800       9801    15640507             Li          762     Spain  Female
# 9877       9878    15572182     Onwuamaeze          505   Germany  Female
# 9895       9896    15796764          Bruno          684   Germany  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Логическое ИЛИ
# При операторе | нужно, чтобы выполнялось хотя бы одно условие. Либо у человека есть карта банка
# (df[’HasCrCard’]), либо количество продуктов, которыми пользуется клиент было больше или равно 3
# (df[‘NumOfProducts’] >= 3)

# %%
df[(df['HasCrCard'])|(df['NumOfProducts']>=3)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 4             5    15737888   Mitchell          850     Spain  Female   43
# 5             6    15574012        Chu          645     Spain    Male   44
# 6             7    15592531   Bartlett          822    France    Male   50
# ...         ...         ...        ...          ...       ...     ...  ...
# 9993       9994    15569266     Rahman          644    France    Male   28
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Логическое НЕ
# При операторе ~ булевая маска обращается: True меняется на False и наоборот. Возвращаем всех
# клиентов, которые проживают не в Испании (~(df[‘Geography’] == ‘Spain’))

# %%
df[~(df["Geography"]=="Spain")]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['Geography'].isin(['France','Germany'])]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Индексация

# %%
df_small=df[(df['Geography']=='Spain')][['Geography','Gender','Age']]
df_small
# Out:
#      Geography  Gender  Age
# 1        Spain  Female   41
# 4        Spain  Female   43
# 5        Spain    Male   44
# 11       Spain    Male   24
# 14       Spain  Female   35
# ...        ...     ...  ...
# 9966     Spain    Male   35
# 9980     Spain    Male   35
# 9987     Spain    Male   30
# 9989     Spain    Male   28
# 9992     Spain    Male   36
#
# [2477 rows x 3 columns]

# %% [markdown]
# #### loc
# Данный метод позволяет взять объект по конкретному ключу строки или столбца

# %%
df_small.loc[1]
# Out:
# Geography     Spain
# Gender       Female
# Age              41
# Name: 1, dtype: object

# %%
df_small.loc[4]
# Out:
# Geography     Spain
# Gender       Female
# Age              43
# Name: 4, dtype: object

# %%
df_small.loc[[1,4,5],['Gender','Age']]
# Out:
#    Gender  Age
# 1  Female   41
# 4  Female   43
# 5    Male   44

# %% [markdown]
# #### iloc
# Данный метод позволяет взять объект по порядковому ключу строки или столбца. И без разницы, какие на самом деле лежат значения ключей в этих строках. В нашем примере есть ключи по индексам 1, 4, 5, но через iloc можем их достать по порядку: 0,1,2, не вдаваясь в подробности, какие именно индексы у этих объектов

# %%
df_small.head()
# Out:
#    Geography  Gender  Age
# 1      Spain  Female   41
# 4      Spain  Female   43
# 5      Spain    Male   44
# 11     Spain    Male   24
# 14     Spain  Female   35

# %%
df_small.iloc[[0,1,2]]
# Out:
#   Geography  Gender  Age
# 1     Spain  Female   41
# 4     Spain  Female   43
# 5     Spain    Male   44

# %%
df_small.iloc[2476]
# Out:
# Geography    Spain
# Gender        Male
# Age             36
# Name: 9992, dtype: object

# %%
df_small.iloc[0,[0,2]]
# Out:
# Geography    Spain
# Age             41
# Name: 1, dtype: object

# %% [markdown]
# Выводит строчку с индексом 0 и столбцы с индексом 0,2

# %% [markdown]
# ### Сортировки

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %% [markdown]
# Сортирует по возрасту от меньшего к большему

# %%
df.sort_values('Age', ascending=False)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6443       6444    15764927       Rogova          753    France    Male   92
# 6759       6760    15660878        T'ien          705    France    Male   92
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 3033       3034    15578006          Yao          787    France  Female   85
# 3387       3388    15798024         Lori          537   Germany    Male   84
# ...         ...         ...          ...          ...       ...     ...  ...
# 9782       9783    15728829       Weigel          509    France    Male   18
# 2141       2142    15758372      Wallace          674    France    Male   18
# 9501       9502    15634146          Hou          835   Germany    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 1619       1620    15770309     McDonald          656    France    Male   18
#
# ...

# %% [markdown]
# Сортирует по возрасту от большего к меньшему

# %%
df.sort_values(['Age','CreditScore'])
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 9782       9783    15728829           Weigel          509    France    Male
# 1678       1679    15569178        Kharlamov          570    France  Female
# 9029       9030    15722701            Bruno          594   Germany    Male
# 7334       7335    15759133          Vaguine          616    France    Male
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# ...         ...         ...              ...          ...       ...     ...
# 3387       3388    15798024             Lori          537   Germany    Male
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6759       6760    15660878            T'ien          705    France    Male
# 6443       6444    15764927           Rogova          753    France    Male
#
# ...

# %% [markdown]
# Сортирует по возрасту и кредитному потенциалу от большего к меньшему по обоим столбцам

# %%
df.sort_values(['Age','CreditScore'],ascending=False)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 6443       6444    15764927           Rogova          753    France    Male
# 6759       6760    15660878            T'ien          705    France    Male
# 2458       2459    15813303          Rearick          513     Spain    Male
# 3033       3034    15578006              Yao          787    France  Female
# 3387       3388    15798024             Lori          537   Germany    Male
# ...         ...         ...              ...          ...       ...     ...
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# 7334       7335    15759133          Vaguine          616    France    Male
# 9029       9030    15722701            Bruno          594   Germany    Male
# 1678       1679    15569178        Kharlamov          570    France  Female
# 9782       9783    15728829           Weigel          509    France    Male
#
# ...

# %% [markdown]
# Сортирует по возрасту и кредитному потенциалу от меньшего к большему по обоим столбцам
