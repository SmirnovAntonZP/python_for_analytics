# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/SmirnovAnton/Desktop/GB_lessons/analitic/Python_for_analitics/Lesson3/Churn_Modelling.csv")
df.sample(5)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  \
# 2959       2960    15673619  Bazhenov          530    France   Male   25
# 3441       3442    15636658  Rozhkova          596    France   Male   36
# 5485       5486    15753837     Young          573     Spain   Male   38
# 6739       6740    15769191    Lipton          509    France   Male   55
# 1733       1734    15752508  Docherty          614   Germany   Male   32
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2959       9  162560.32              1          1               0
# 3441       2       0.00              2          1               1
# 5485       4       0.00              2          1               1
# 6739       8  132387.91              2          1               1
# 1733       7   99462.80              2          1               1
#
#       EstimatedSalary  Exited
# 2959         64129.03       0
# 3441         12067.39       0
# 5485        196517.43       0
# 6739        170360.11       0
# 1733         51117.06       0

# %%
users = pd.read_csv('/Users/SmirnovAnton/Desktop/GB_lessons/analitic/Python_for_analitics/Lesson3/Churn_Modelling.csv', sep=',')
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
users.shape
# Out:
# (10000, 14)

# %%
users['new_feature'] = 0
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature
# 0        101348.88       1            0
# 1        112542.58       0            0
# 2        113931.57       1            0
# 3         93826.63       0            0
# 4         79084.10       0            0

# %%
users['Age (days)'] = users['Age'] * 365
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)
# 0        101348.88       1            0       15330
# 1        112542.58       0            0       14965
# 2        113931.57       1            0       15330
# 3         93826.63       0            0       14235
# 4         79084.10       0            0       15695

# %%
for i, row in users.iloc[:2].iterrows():
    print(row)
    print('__' * 30)
# Out:
# RowNumber                  1
# CustomerId          15634602
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                       42
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# new_feature                0
# Age (days)             15330
# Name: 0, dtype: object
# ____________________________________________________________
# RowNumber                  2
# CustomerId          15647311
# Surname                 Hill
# CreditScore              608
# Geography              Spain
# Gender                Female
# Age                       41
# Tenure                     1
# Balance             83807.86
# NumOfProducts              1
# HasCrCard                  0
# IsActiveMember             1
# EstimatedSalary    112542.58
# Exited                     0
# new_feature                0
# Age (days)             14965
# Name: 1, dtype: object
# ____________________________________________________________

# %%
age_days = []

for i, row in users.iterrows():
    age_days.append(row['Age'] * 365)

age_days[:10]
# Out:
# [15330, 14965, 15330, 14235, 15695, 16060, 18250, 10585, 16060, 9855]

# %%
users['Age (days) 2'] = age_days
users.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
# 5        149756.71       1            0       16060         16060
# 6         10062.80       0            0       18250         18250
# 7        119346.88       1            0       10585         10585
# 8         74940.50       0            0       16060         16060
# 9         71725.73       0            0        9855          9855

# %%
def age_to_days(x):
    return x * 365

users['Age (days) 3'] = users['Age'].apply(age_to_days)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
#
#    Age (days) 3
# 0         15330
# 1         14965
# 2         15330
# 3         14235
# 4         15695

# %%
import time
from tqdm import tqdm
tqdm.pandas()


def age_to_days(x):
    time.sleep(0.001)
    return x * 365

users['Age'].progress_apply(age_to_days)
# Out:
# 100%|████████████████████████████████████| 10000/10000 [00:13<00:00, 760.04it/s]
# 0       15330
# 1       14965
# 2       15330
# 3       14235
# 4       15695
#         ...
# 9995    14235
# 9996    12775
# 9997    13140
# 9998    15330
# 9999    10220
# Name: Age, Length: 10000, dtype: int64

# %%
users.drop(columns='new_feature')
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
#
#    Age (days) 3
# 0         15330
# 1         14965
# 2         15330
# 3         14235
# 4         15695

# %% [markdown]
# Вывод таблицы без колонки(но сама колонка остается в датафрейме)

# %%
users = users.drop(columns='new_feature')
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age (days)  Age (days) 2  Age (days) 3
# 0        101348.88       1       15330         15330         15330
# 1        112542.58       0       14965         14965         14965
# 2        113931.57       1       15330         15330         15330
# 3         93826.63       0       14235         14235         14235
# 4         79084.10       0       15695         15695         15695

# %% [markdown]
# Полное удаление таблицы

# %%
users['new_feature'] = 0

# %%
users.drop(columns='new_feature', inplace=True)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age (days)  Age (days) 2  Age (days) 3
# 0        101348.88       1       15330         15330         15330
# 1        112542.58       0       14965         14965         14965
# 2        113931.57       1       15330         15330         15330
# 3         93826.63       0       14235         14235         14235
# 4         79084.10       0       15695         15695         15695

# %% [markdown]
# Удаление колонки и перезапись датасета сразу(inplace)

# %%
users.drop(columns=['Age (days)', 'Age (days) 2', 'Age (days) 3'], inplace=True)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# Удаление нескольких колонок

# %% [markdown]
# ## Изменение существующих признаков
# ### .loc

# %%
users['target'] = 0
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  target
# 0        101348.88       1       0
# 1        112542.58       0       0
# 2        113931.57       1       0
# 3         93826.63       0       0
# 4         79084.10       0       0

# %% [markdown]
# Создание новой колонки со значением 0

# %%
users.loc[users['Geography'] == 'France']
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 6          7       0.00              2          1               1
# 8          4  142051.07              2          0               1
# ...      ...        ...            ...        ...             ...
# 9994       2       0.00              2          0               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  target
# 0           101348.88       1       0
# 2           113931.57       1       0
# 3            93826.63       0       0
# 6            10062.80       0       0
# 8            74940.50       0       0
# ...               ...     ...     ...
# 9994        167773.55       0       0
# 9995         96270.64       0       0
# 9996        101699.77       0       0
# 9997         42085.58       1       0
# 9999         38190.78       0       0
#
# [5014 rows x 15 columns]

# %% [markdown]
# Вывод строк по индексу колонки география со значением франция

# %%
users.loc[users['Geography'] == 'France', 'target']
# Out:
# 0       0
# 2       0
# 3       0
# 6       0
# 8       0
#        ..
# 9994    0
# 9995    0
# 9996    0
# 9997    0
# 9999    0
# Name: target, Length: 5014, dtype: int64

# %% [markdown]
# Вывод строк по индексу колонки география и таргет со значением франция и 0 соответственно

# %%
# users[users['Geography'] == 'France']['target'] = 1
# users.head()

# %%
users.loc[users['Geography'] == 'France','target'] = 1
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  Tenure  \
# 0          1    15634602  Hargrave          619    France      F   42       2
# 1          2    15647311      Hill          608     Spain      F   41       1
# 2          3    15619304      Onio          502    France      F   42       8
# 3          4    15701354      Boni          699    France      F   39       1
# 4          5    15737888  Mitchell          850     Spain      F   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  target
# 0       1       1
# 1       0       0
# 2       1       1
# 3       0       1
# 4       0       0

# %% [markdown]
# Перезапись данных в колонке таргет с 0 на 1 с условием что географи == франс

# %% [markdown]
# ## .replace

# %%
users['Gender'].replace({'Female' : 'F', 'Male': 'M'}, inplace =True)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  Tenure  \
# 0          1    15634602  Hargrave          619    France      F   42       2
# 1          2    15647311      Hill          608     Spain      F   41       1
# 2          3    15619304      Onio          502    France      F   42       8
# 3          4    15701354      Boni          699    France      F   39       1
# 4          5    15737888  Mitchell          850     Spain      F   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  target
# 0       1       1
# 1       0       0
# 2       1       1
# 3       0       1
# 4       0       0

# %% [markdown]
# ## Метод агрегации

# %%
users['Age'].agg(['min','max'])
# Out:
# min    18
# max    92
# Name: Age, dtype: int64

# %%
users.agg({
    'Age': ['min','max'],
    'EstimatedSalary': 'mean'
})
# Out:
#        Age  EstimatedSalary
# min   18.0              NaN
# max   92.0              NaN
# mean   NaN    100090.239881

# %% [markdown]
# Сводная таблица

# %%
users.agg(
    min_age=('Age','min'),
    max_age=('Age','max'),
    mean_salary=('EstimatedSalary', 'mean')
)
# Out:
#               Age  EstimatedSalary
# min_age      18.0              NaN
# max_age      92.0              NaN
# mean_salary   NaN    100090.239881

# %% [markdown]
# ##  Методы объединения

# %%
bank = pd.read_csv('/Users/SmirnovAnton/Desktop/GB_lessons/analitic/Python_for_analitics/Lesson3/Churn_Modelling.csv', sep =',')
bank.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
bank.shape
# Out:
# (10000, 14)

# %%
merged = users.merge(bank,left_on = 'CustomerId',right_on='CustomerId')
merged.head()
# Out:
#    RowNumber_x  CustomerId Surname_x  CreditScore_x Geography_x Gender_x  \
# 0            1    15634602  Hargrave            619      France        F
# 1            2    15647311      Hill            608       Spain        F
# 2            3    15619304      Onio            502      France        F
# 3            4    15701354      Boni            699      France        F
# 4            5    15737888  Mitchell            850       Spain        F
#
#    Age_x  Tenure_x  Balance_x  NumOfProducts_x  ...  Geography_y  Gender_y  \
# 0     42         2       0.00                1  ...       France    Female
# 1     41         1   83807.86                1  ...        Spain    Female
# 2     42         8  159660.80                3  ...       France    Female
# 3     39         1       0.00                2  ...       France    Female
# 4     43         2  125510.82                1  ...        Spain    Female
#
#    Age_y  Tenure_y  Balance_y  NumOfProducts_y HasCrCard_y  IsActiveMember_y  \
# 0     42         2       0.00                1           1                 1
# 1     41         1   83807.86                1           0                 1
# 2     42         8  159660.80                3           1                 0
# 3     39         1       0.00                2           0                 0
# 4     43         2  125510.82                1           1                 1
#
#   EstimatedSalary_y Exited_y
# 0         101348.88        1
# 1         112542.58        0
# 2         113931.57        1
# 3          93826.63        0
# 4          79084.10        0
#
# [5 rows x 28 columns]

# %%
users_id = users.set_index('CustomerId')
users_id.head()
# Out:
#             RowNumber   Surname  CreditScore Geography Gender  Age  Tenure  \
# CustomerId
# 15634602            1  Hargrave          619    France      F   42       2
# 15647311            2      Hill          608     Spain      F   41       1
# 15619304            3      Onio          502    France      F   42       8
# 15701354            4      Boni          699    France      F   39       1
# 15737888            5  Mitchell          850     Spain      F   43       2
#
#               Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15634602         0.00              1          1               1
# 15647311     83807.86              1          0               1
# 15619304    159660.80              3          1               0
# 15701354         0.00              2          0               0
# 15737888    125510.82              1          1               1
#
#             EstimatedSalary  Exited  target
# CustomerId
# 15634602          101348.88       1       1
# 15647311          112542.58       0       0
# 15619304          113931.57       1       1
# 15701354           93826.63       0       1
# 15737888           79084.10       0       0

# %%
bank_id = bank.set_index('CustomerId')
bank_id.head()
# Out:
#             RowNumber   Surname  CreditScore Geography  Gender  Age  Tenure  \
# CustomerId
# 15634602            1  Hargrave          619    France  Female   42       2
# 15647311            2      Hill          608     Spain  Female   41       1
# 15619304            3      Onio          502    France  Female   42       8
# 15701354            4      Boni          699    France  Female   39       1
# 15737888            5  Mitchell          850     Spain  Female   43       2
#
#               Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15634602         0.00              1          1               1
# 15647311     83807.86              1          0               1
# 15619304    159660.80              3          1               0
# 15701354         0.00              2          0               0
# 15737888    125510.82              1          1               1
#
#             EstimatedSalary  Exited
# CustomerId
# 15634602          101348.88       1
# 15647311          112542.58       0
# 15619304          113931.57       1
# 15701354           93826.63       0
# 15737888           79084.10       0

# %%
# bank_id.join(users_id).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3w/z8lz0mhx3xv6jy9tlj7bfbpc0000gn/T/ipykernel_43072/1018575708.py in <module>
# ----> 1 bank_id.join(users_id).head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9261         5  K1  A5   B1
#    9262         """
# -> 9263         return self._join_compat(
#    9264             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9265         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9292                     sort=sort,
#    9293                 )
# -> 9294             return merge(
#    9295                 self,
#    9296                 other,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     716         join_index, left_indexer, right_indexer = self._get_join_info()
#     717
# --> 718         llabels, rlabels = _items_overlap_with_suffix(
#     719             self.left._info_axis, self.right._info_axis, self.suffixes
#     720         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2315
#    2316     if not lsuffix and not rsuffix:
# -> 2317         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2318
#    2319     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['RowNumber', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# bank_id.join(users_id).reset_index().head()

# %%
toy_df1 = pd.DataFrame({
    'col_1': [1, 2, 3],
    'col_2': [9, 9, 9]
})

toy_df2 = pd.DataFrame({
    'col_1': [3, 4],
    'col_3': [0, 0]
})

display(toy_df1, toy_df2)
# Out:
#    col_1  col_2
# 0      1      9
# 1      2      9
# 2      3      9
#    col_1  col_3
# 0      3      0
# 1      4      0

# %%
toy_df1.merge(toy_df2, how='left')
# Out:
#    col_1  col_2  col_3
# 0      1      9    NaN
# 1      2      9    NaN
# 2      3      9    0.0

# %%
toy_df1.merge(toy_df2, how='right')
# Out:
#    col_1  col_2  col_3
# 0      3    9.0      0
# 1      4    NaN      0

# %%
toy_df1.merge(toy_df2, how='inner')
# Out:
#    col_1  col_2  col_3
# 0      3      9      0

# %%
toy_df1.merge(toy_df2, how='outer')
# Out:
#    col_1  col_2  col_3
# 0      1    9.0    NaN
# 1      2    9.0    NaN
# 2      3    9.0    0.0
# 3      4    NaN    0.0

# %%
merged_left = bank.merge(users, on='CustomerId', how='left')
merged_left.shape
# Out:
# (10000, 28)

# %%
merged_left.isna().sum()
# Out:
# RowNumber_x          0
# CustomerId           0
# Surname_x            0
# CreditScore_x        0
# Geography_x          0
# Gender_x             0
# Age_x                0
# Tenure_x             0
# Balance_x            0
# NumOfProducts_x      0
# HasCrCard_x          0
# IsActiveMember_x     0
# EstimatedSalary_x    0
# Exited_x             0
# RowNumber_y          0
# Surname_y            0
# CreditScore_y        0
# Geography_y          0
# Gender_y             0
# Age_y                0
# Tenure_y             0
# Balance_y            0
# NumOfProducts_y      0
# HasCrCard_y          0
# IsActiveMember_y     0
# EstimatedSalary_y    0
# Exited_y             0
# target               0
# dtype: int64

# %%
# merged_left[merged_left['Age'].isna()]

# %% [markdown]
# ## Методы группировок
# ### groupby

# %%
toy_df = pd.DataFrame({
    'client_id': [1, 2, 2, 3, 1, 1],
    'item': ['chocolate', 'cheese', 'ham', 'candy', 'chair', 'book'],
    'price': [68, 280, 302, 39, 2099, 1089]
})

toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
grouped = toy_df.groupby('client_id')
grouped

# %%
grouped.groups
# Out:
# {1: [0, 4, 5], 2: [1, 2], 3: [3]}

# %%
grouped.sum()
# Out:
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
grouped.agg({'price': ['sum', 'min', 'max']})
# Out:
#           price
#             sum  min   max
# client_id
# 1          3256   68  2099
# 2           582  280   302
# 3            39   39    39

# %%
users.groupby('Geography').agg({'Age': ['mean'], 'EstimatedSalary': ['min']})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %% [markdown]
# ## pivot_table

# %%
toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
toy_df.pivot_table(index='client_id',
                   values='price',
                   aggfunc='sum')
# Out:
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
users.pivot_table(index='Geography',
                  aggfunc={'Age': ['mean'], 'EstimatedSalary': 'min'})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %%
users.pivot_table(index='Geography',
                  columns='Gender', 
                  values='EstimatedSalary',
                  aggfunc='mean',
                  margins=True,
                  margins_name='Total')
# Out:
# Gender                 F              M          Total
# Geography
# France      99564.252755  100174.252495   99899.180814
# Germany    102446.424124   99905.033959  101113.435102
# Spain      100734.107475   98425.687680   99440.572281
# Total      100601.541382   99664.576931  100090.239881

# %% [markdown]
# ## crosstab

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'])
# Out:
# Gender        F     M
# Geography
# France     2261  2753
# Germany    1193  1316
# Spain      1089  1388

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            values=users['EstimatedSalary'],
            aggfunc='mean')
# Out:
# Gender                 F              M
# Geography
# France      99564.252755  100174.252495
# Germany    102446.424124   99905.033959
# Spain      100734.107475   98425.687680

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            normalize='all')
# Out:
# Gender          F       M
# Geography
# France     0.2261  0.2753
# Germany    0.1193  0.1316
# Spain      0.1089  0.1388

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            normalize='index')
# Out:
# Gender            F         M
# Geography
# France     0.450937  0.549063
# Germany    0.475488  0.524512
# Spain      0.439645  0.560355

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            normalize='columns')
# Out:
# Gender            F         M
# Geography
# France     0.497689  0.504490
# Germany    0.262602  0.241158
# Spain      0.239709  0.254352

# %% [markdown]
# ## Встроенные визуализации

# %%
users['Age'].hist();

# %%
data = users.groupby('Gender').count()['Age']
data.name = 'Gender'
data
# Out:
# Gender
# F    4543
# M    5457
# Name: Gender, dtype: int64

# %%
data.plot.pie(y='Gender');

# %%
users.iloc[:100].plot.scatter(x='Age', y='EstimatedSalary');

# %%
data = bank.groupby('Tenure').count()['Balance']
data.name = 'num_clients'
data
# Out:
# Tenure
# 0      413
# 1     1035
# 2     1048
# 3     1009
# 4      989
# 5     1012
# 6      967
# 7     1028
# 8     1025
# 9      984
# 10     490
# Name: num_clients, dtype: int64

# %%
data.plot.bar(width=0.8);
